# %%
n=int(input("enter any integer number:"))
if n%2==0:
    print("even number")
else:
    print("odd number")

# %%
fact=1
n=int(input("enter any integer value:"))
for x in range(1,n+1):
    fact=fact*x
print("factorial of ",n,"is",fact)

# %%
def fact(n):
    if n<=1:
        return 1
    else:
        n=n*fact(n-1)
        return n
n=int(input("Enter the any integer value:"))
print("factorial of integer",n,"is",fact(n))

# %%
list=["apple","mango"]
print(list)

# %%
x=int(input("Enter the x value:"))
y=int(input("Enter the y value:"))
temp=x
x=y
y=temp
print("Swapping of x value:",x)
print("Swapping of y value:",y)

# %%
x=input("enter your are male(y/n):")
if x==y or x==Y:
    print("congratulation your male:")
else:
    print("sadly your female")

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)
def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %% [markdown]
# # Prima_data data_cleaning

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Ankit\\Desktop\\Data_Pre_Processing\\pima-data.csv")
df.head(10)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
# 5         5           116            74          0        0  25.6      0.201
# 6         3            78            50         32       88  31.0      0.248
# 7        10           115             0          0        0  35.3      0.134
# 8         2           197            70         45      543  30.5      0.158
# 9         8           125            96          0        0   0.0      0.232
#
#    age    skin  diabetes
# 0   50  1.3790      True
# 1   31  1.1426     False
# 2   32  0.0000      True
# ...

# %% [markdown]
# # checking null values

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# # check corelation features

# %%
df.corr()
# Out:
#               num_preg  glucose_conc  diastolic_bp  thickness   insulin  \
# num_preg      1.000000      0.129459      0.141282  -0.081672 -0.073535
# glucose_conc  0.129459      1.000000      0.152590   0.057328  0.331357
# diastolic_bp  0.141282      0.152590      1.000000   0.207371  0.088933
# thickness    -0.081672      0.057328      0.207371   1.000000  0.436783
# insulin      -0.073535      0.331357      0.088933   0.436783  1.000000
# bmi           0.017683      0.221071      0.281805   0.392573  0.197859
# diab_pred    -0.033523      0.137337      0.041265   0.183928  0.185071
# age           0.544341      0.263514      0.239528  -0.113970 -0.042163
# skin         -0.081672      0.057328      0.207371   1.000000  0.436783
# diabetes      0.221898      0.466581      0.065068   0.074752  0.130548
#
#                    bmi  diab_pred       age      skin  diabetes
# num_preg      0.017683  -0.033523  0.544341 -0.081672  0.221898
# ...

# %%
import matplotlib.pyplot as plt

def fun(df,size=11):
    corr=df.corr()
    fig, ax= plt.subplots(figsize=(size,size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)),corr.columns)
    plt.yticks(range(len(corr.columns)),corr.columns)
fun(df)

# %%
del df["skin"]

# %%
df.head(10)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
# 5         5           116            74          0        0  25.6      0.201
# 6         3            78            50         32       88  31.0      0.248
# 7        10           115             0          0        0  35.3      0.134
# 8         2           197            70         45      543  30.5      0.158
# 9         8           125            96          0        0   0.0      0.232
#
#    age  diabetes
# 0   50      True
# 1   31     False
# 2   32      True
# 3   21     False
# 4   33      True
# ...

# %%
fun(df)

# %% [markdown]
# # Data encoding

# %%
diat_map = {True:1,False:0}
df['diabetes'] = df['diabetes'].map(diat_map)
df.head(10)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
# 5         5           116            74          0        0  25.6      0.201
# 6         3            78            50         32       88  31.0      0.248
# 7        10           115             0          0        0  35.3      0.134
# 8         2           197            70         45      543  30.5      0.158
# 9         8           125            96          0        0   0.0      0.232
#
#    age  diabetes
# 0   50         1
# 1   31         0
# 2   32         1
# 3   21         0
# 4   33         1
# ...

# %% [markdown]
# # impute missing values replace

# %%
from sklearn.model_selection import train_test_split
features_col_names = ['num_preg','glucose_conc','diastolic_bp','thickness','insulin','bmi','diab_pred','age','diabetes']
predicted_col_names = ['diabetes']

x = df[features_col_names].values
y = df[predicted_col_names].values

split_size = 0.30

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = split_size , random_state = 42)

print("Training_set{0:0.2f}% " .format((float(len(x_train))/float(len(df.index)))*100))
print('test set{0:0.2f}%'.format((float(len(x_test))/float(len(df.index)))*100))
# Out:
# Training_set69.92%
# test set30.08%

# %%
from sklearn.impute import SimpleImputer

fill = SimpleImputer(missing_values = 0 ,strategy = "mean")
x_train  = fill.fit_transform(x_train)
x_test = fill.fit_transform(x_test)

print(x_train)
# Out:
# [[  1.          95.          60.         ...   0.26        22.
#     1.        ]
#  [  5.         105.          72.         ...   0.159       28.
#     1.        ]
#  [  4.34056399 135.          68.         ...   0.365       24.
#     1.        ]
#  ...
#  [ 10.         101.          86.         ...   1.136       38.
#     1.        ]
#  [  4.34056399 141.          72.24131274 ...   0.205       29.
#     1.        ]
#  [  4.34056399 125.          96.         ...   0.262       21.
#     1.        ]]
