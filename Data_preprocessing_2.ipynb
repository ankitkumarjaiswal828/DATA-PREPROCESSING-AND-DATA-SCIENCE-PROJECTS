# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Fill the missing values by mean ,median , mode

# %%
ds = pd.read_csv(r'C:\\Users\\ANKIT\\Documents\\udemy ML coures\\kaggle datasets\house-prices-advanced-regression-techniques\\train.csv')
ds
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
ds.shape
# Out:
# (1460, 81)

# %%
ds.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
ds.isnull().sum().sum()
# Out:
# 6965

# %%
ds.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
sns.heatmap(ds.isnull())
# Out:
# <AxesSubplot:>

# %%
null_var = ds.isnull().sum()/ds.shape[0]*100    #error in percentages
null_var
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
mising_values = null_var[null_var>20].keys()
mising_values
# Out:
# Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
drop_errors = ds.drop(columns = mising_values)
drop_errors.shape
# Out:
# (1460, 76)

# %%
ds_2 = drop_errors.select_dtypes(include = ['int64' , 'float64'])
ds_2.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
sns.heatmap(ds_2.isnull())
# Out:
# <AxesSubplot:>

# %%
ds_2[ds_2.isnull().any(axis = 1)]
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 7        8          60          NaN    10382            7            6
# 12      13          20          NaN    12968            5            6
# 14      15          20          NaN    10920            6            5
# 16      17          20          NaN    11241            6            7
# 24      25          20          NaN     8246            5            8
# ...    ...         ...          ...      ...          ...          ...
# 1443  1444          30          NaN     8854            6            6
# 1446  1447          20          NaN    26142            5            7
# 1449  1450         180         21.0     1533            5            7
# 1450  1451          90         60.0     9000            5            5
# 1453  1454          20         90.0    17217            5            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
ds_2.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
mis_values = [var for  var in ds_2.columns if ds_2[var].isnull().sum()>0]
mis_values
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
sns.set()
for i, var in enumerate(mis_values):
    plt.subplot(2,2,i+1)
    sns.distplot(ds_2[var],bins = 20, kde_kws = {'linewidth':5 , 'color':'r'})

# %% [markdown]
# # CALCULATE THE MEAN VALUES TO FILL IN MISSING DATASETS POSITION

# %%
ds_mean = ds_2.fillna(ds_2.mean())
ds_mean.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %%
sns.heatmap(ds_mean.isnull())
# Out:
# <AxesSubplot:>

# %%
ds_mean.shape
# Out:
# (1460, 38)

# %%
sns.set()
for i, var in enumerate(mis_values):
    plt.subplot(2,2,i+1)
    sns.distplot(ds_2[var],bins = 20, kde_kws = {'linewidth':5 , 'color':'r'},label = 'normal distribution')
    sns.distplot(ds_mean[var],bins = 20, kde_kws = {'linewidth':5 , 'color':'b'},label = 'skew distribution')
    sns.distplot(ds[var],bins = 20, kde_kws = {'linewidth':5 , 'color':'r'},label = 'original datasets distribution')
    plt.legend()

# %%
sns.boxplot(ds_mean[var])
# Out:
# <AxesSubplot:xlabel='GarageYrBlt', ylabel='Density'>

# %%
sns.boxplot(ds_2[var])
# Out:
# <AxesSubplot:xlabel='GarageYrBlt', ylabel='Density'>

# %%
sns.boxplot(ds[var])
# Out:
# <AxesSubplot:xlabel='GarageYrBlt', ylabel='Density'>

# %%
for i, var in enumerate(mis_values):
    plt.subplot(3,1,1)
    sns.boxplot(ds[var])
    plt.subplot(3,1,2)
    sns.boxplot(ds_2[var])
    plt.subplot(3,1,3)
    sns.boxplot(ds_mean[var])

# %%
ds_concat = pd.concat([ds[mis_values],ds_mean[mis_values],ds_median[mis_values]])
ds_concat[ds_concat.isnull().any(axis=1)]

# %% [markdown]
# # FILL THE MISSING VALUES BY MEDIAN

# %%
ds_median =ds_2.fillna(ds_2.median())
ds_median.isnull().sum().sum()
# Out:
# 0

# %%
sns.set()
for i, var in enumerate(mis_values):
    plt.subplot(2,2,i+1)
    sns.distplot(ds[var],bins = 20, kde_kws = {'linewidth':5 , 'color':'r'},label = 'original datasets')
    sns.distplot(ds_mean[var],bins = 20, kde_kws = {'linewidth':5 , 'color':'b'},label = 'mean replaced datasets')
    sns.distplot(ds_median[var],bins = 20, kde_kws = {'linewidth':5 , 'color':'r'},label = 'median replaced dataset')
    plt.legend()

# %% [markdown]
# Data Distribution
