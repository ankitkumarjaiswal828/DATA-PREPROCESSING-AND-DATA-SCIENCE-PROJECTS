# %% [markdown]
# # imputing missing values by class variables(measure the central tendency for each class)

# %% [markdown]
# It mean we are find each class of the mean separetly, then we are fill mean value on  the each class of missing datasets position

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
ds = pd.read_csv(r'C:\Users\ANKIT\Documents\udemy ML coures\kaggle datasets\house-prices-advanced-regression-techniques\train.csv')
ds.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.set_option('max_columns',None)
pd.set_option('max_rows',None)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
ds.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
ds.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
ds.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
ds.isnull().sum().sum() # no of missing values present in datasets
# Out:
# 6965

# %%
miss_features = ['LotFrontage','MasVnrArea','GarageYrBlt']
ds[miss_features][ds[miss_features].isnull().any(axis = 1)]
# Out:
#       LotFrontage  MasVnrArea  GarageYrBlt
# 7             NaN       240.0       1973.0
# 12            NaN         0.0       1962.0
# 14            NaN       212.0       1960.0
# 16            NaN       180.0       1970.0
# 24            NaN         0.0       1968.0
# ...           ...         ...          ...
# 1443          NaN         0.0       1916.0
# 1446          NaN       189.0       1962.0
# 1449         21.0         0.0          NaN
# 1450         60.0         0.0          NaN
# 1453         90.0         0.0          NaN
#
# [339 rows x 3 columns]

# %%
ds['LotConfig'].unique() #check which class present in LOtCONFIG
# Out:
# array(['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3'], dtype=object)

# %%
ds[ds.loc[:,'LotConfig']=='Inside']           # it is gives the values in comparison of lotfrontage and lotconfig
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
ds[ds.loc[:,'LotConfig'] == 'Inside']['LotFrontage']
# Out:
# 0       65.0
# 2       68.0
# 5       85.0
# 6       75.0
# 8       51.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1052, dtype: float64

# %% [markdown]
# # REPLACE WITH MEAN VALUES OF NAN VALUES

# %%
ds[ds.loc[:,'LotConfig']=='Inside']['LotFrontage'].replace(np.nan,ds[ds.loc[:,'LotConfig']=='Inside']['LotFrontage'].mean())
# Out:
# 0       65.0
# 2       68.0
# 5       85.0
# 6       75.0
# 8       51.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1052, dtype: float64

# %% [markdown]
# # now fill all missing values with respect to class like(inside , FR2,FR3,cornor etc)

# %%
ds_copy = ds.copy()
for var_class in ds['LotConfig'].unique():
    ds_copy.update(ds[ds.loc[:,'LotConfig']==var_class]['LotFrontage'].replace(np.nan,ds[ds.loc[:,'LotConfig']==var_class]['LotFrontage'].mean()))

# %% [markdown]
# ds_copy.isnull().sum()

# %% [markdown]
# FILL THE MISSING VALUES WITH DOMAIN VALUES

# %%
ds_copy = ds.copy()
num_vars_miss = ['LotFrontage','MasVnrArea','GarageYrBlt']
cat_vars = ['LotConfig','MasVnrType','GarageType']
for cat_var , num_var_miss in zip(cat_vars , num_vars_miss):
    for var_class in ds[cat_var].unique():
        ds_copy.update(ds[ds.loc[:,cat_var]==var_class][num_var_miss].replace(np.nan,ds[ds.loc[:,cat_var]==var_class][num_var_miss].mean()))

# %%
ds_copy[num_vars_miss].isnull().sum()
# Out:
# LotFrontage     0
# MasVnrArea      8
# GarageYrBlt    81
# dtype: int64

# %%
ds_copy[ds_copy[['MasVnrType']].isnull().any(axis =1)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 234    235          60       RL    67.715686     7851   Pave   NaN      Reg
# 529    530          20       RL    59.911111    32668   Pave   NaN      IR1
# 650    651          60       FV    65.000000     8125   Pave   NaN      Reg
# 936    937          20       RL    67.000000    10083   Pave   NaN      Reg
# 973    974          20       FV    95.000000    11639   Pave   NaN      Reg
# 977    978         120       FV    35.000000     4274   Pave  Pave      IR1
# 1243  1244          20       RL   107.000000    13891   Pave   NaN      Reg
# 1278  1279          60       RL    75.000000     9473   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 234          Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 529          Lvl    AllPub   CulDSac       Gtl      Crawfor       Norm
# ...

# %%
ds_copy[ds_copy[['GarageType']].isnull().any(axis =1)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 39      40          90       RL    65.000000     6040   Pave   NaN      Reg
# 48      49         190       RM    33.000000     4456   Pave   NaN      Reg
# 78      79          90       RL    72.000000    10778   Pave   NaN      Reg
# 88      89          50  C (all)   105.000000     8470   Pave   NaN      IR1
# 89      90          20       RL    60.000000     8070   Pave   NaN      Reg
# 99     100          20       RL    77.000000     9320   Pave   NaN      IR1
# 108    109          50       RM    85.000000     8500   Pave   NaN      Reg
# 125    126         190       RM    60.000000     6780   Pave   NaN      Reg
# 127    128          45       RM    55.000000     4388   Pave   NaN      IR1
# 140    141          20       RL    70.000000    10500   Pave   NaN      Reg
# 148    149          20       RL    63.000000     7500   Pave   NaN      Reg
# ...

# %% [markdown]
# fill the NAN values with MEAN

# %%
ds_copy = ds.copy()
num_vars_miss = ['LotFrontage','MasVnrArea','GarageYrBlt']
cat_vars = ['LotConfig','Exterior2nd','KitchenQual']
for cat_var , num_var_miss in zip(cat_vars , num_vars_miss):
    for var_class in ds[cat_var].unique():
        ds_copy.update(ds[ds.loc[:,cat_var]==var_class][num_var_miss].replace(np.nan,ds[ds.loc[:,cat_var]==var_class][num_var_miss].mean()))

# %%
ds_copy[num_vars_miss].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %% [markdown]
# Data Distribution

# %%
plt.figure(figsize = (10,10))
sns.set()
for i, var in enumerate(num_vars_miss):
    plt.subplot(2,2,i+1)
    sns.distplot(ds[var],bins = 20, kde_kws = {'linewidth':5 , 'color':'r'},label = 'original datasets')
    sns.distplot(ds_copy[var],bins = 20, kde_kws = {'linewidth':5 , 'color':'b'},label = 'mean replaced datasets')
    plt.legend()

# %% [markdown]
# Now fill the nan values with median

# %%
ds_copy_median = ds.copy()
num_vars_miss = ['LotFrontage','MasVnrArea','GarageYrBlt']
cat_vars = ['LotConfig','Exterior2nd','KitchenQual']
for cat_var , num_var_miss in zip(cat_vars , num_vars_miss):
    for var_class in ds[cat_var].unique():
        ds_copy_median.update(ds[ds.loc[:,cat_var]==var_class][num_var_miss].replace(np.nan,ds[ds.loc[:,cat_var]==var_class][num_var_miss].median()))

# %%
ds_copy_median[num_vars_miss].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %% [markdown]
# Data Oistribution

# %%
plt.figure(figsize = (10,10))
sns.set()
for i, var in enumerate(num_vars_miss):
    plt.subplot(2,2,i+1)
    sns.distplot(ds[var],bins = 20, kde_kws = {'linewidth':5 , 'color':'r'},label = 'original datasets')
    sns.distplot(ds_copy[var],bins = 20, kde_kws = {'linewidth':5 , 'color':'green'},label = 'mean value')
    sns.distplot(ds_copy_median[var],bins = 20, kde_kws = {'linewidth':5 , 'color':'b'},label = 'median values')
    plt.legend()

# %% [markdown]
# Boxplot for checking outlier

# %%
for i, var in enumerate(num_vars_miss):
    plt.figure(figsize = (10,10))
    plt.subplot(3,1,1)
    sns.boxplot(ds[var])
    plt.subplot(3,1,2)
    sns.boxplot(ds_copy[var])
    plt.subplot(3,1,3)
    sns.boxplot(ds_copy_median[var])
